# %%
# This notebook is used to
# 1. Refine the classifiers to mitigate data imbalance
# 2. Create ensemble classifier
# 3. Perform feature ablation

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import copy
from joblib import dump, load

plt.style.use('bmh')
mpl.rcParams.update({
    "grid.linestyle" : "dashed",
    "axes.facecolor" : "white",
    "axes.spines.top" : False,
    "axes.spines.right" : False,
    "legend.frameon" : False,
    "figure.figsize" : (8, 5),
    "figure.dpi" : 300,
})

# suppress sklearn deprecated warnings
import warnings
def warn(*args, **kwargs): pass
warnings.warn = warn

# %%
# TODO make test for dataset with creatina column
# Dataset without thyroid = 18 features (including survive7y)
# Dataset with thyroid = 27 features (including survive7y)
# With columns that have missing values, 23 and 32
# Default 18
n_features = 32
extra_path = n_features != 27 and n_features != 18
dropped_na_key = "dropped_na/"
mean_key = "mean/"
path = f"data/{n_features}features/{mean_key if extra_path else '' }"
path_models = f"models/{n_features}features/{mean_key if extra_path else '' }"
path_images = f"figures/{n_features}features/{mean_key if extra_path else '' }"
output_models = f"models_output/{n_features}features/{mean_key if extra_path else '' }"
print(path_models)
print(path)
# Out:
# models/32features/mean/
# data/32features/mean/

# %% [markdown]
# ### Sampling
# Oversample and undersample methods to mitigate data imbalance

# %%
# Load Data for sampling
df_train = pd.read_csv(f"{path}train.csv", index_col=0)
df_valid = pd.read_csv(f"{path}valid.csv", index_col=0)
df_test = pd.read_csv(f"{path}test.csv", index_col=0)
print(len(df_train)+len(df_valid)+len(df_test))
feat_names = list(df_train.columns)
train, valid, test = df_train.to_numpy(), df_valid.to_numpy(), df_test.to_numpy()
X_train, y_train = train[:, :-1], train[:, -1]
X_valid, y_valid = valid[:, :-1], valid[:, -1]
X_test, y_test = test[:, :-1], test[:, -1]

from utils import get_preprocess_std_num
preprocess_std = get_preprocess_std_num(feat_names)


# Preprocessed ready-to-use train and valid set
process_tmp = preprocess_std.fit(X_train)
X_train_std = process_tmp.transform(X_train)
X_valid_std = process_tmp.transform(X_valid)
# Out:
# 6447

# %%
from imblearn.over_sampling import SMOTE, BorderlineSMOTE, SVMSMOTE
from collections import Counter
from train import evaluate
from utils import datasetSampler
from functools import partial
from train import evaluate
from contextlib import redirect_stdout
# Over sample to 50/
overs = [
    ("smote", SMOTE(sampling_strategy=1.0, k_neighbors=1)),
    ("bordersmote", BorderlineSMOTE(sampling_strategy=1.0, k_neighbors=1)),
    ("svmsmote", SVMSMOTE(sampling_strategy=1.0, k_neighbors=1)), 
    # ADASYN(sampling_strategy=1.0, n_neighbors=1)
]

sampler = partial(
    datasetSampler,
    # missing parameters: model, overSampler, sampling_strategy
    X_train=X_train,
    y_train=y_train,
    X_valid=X_valid,
    y_valid=y_valid,
    useUnderSampler = False
)
random_ratio = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
name_models = ["lr", "svc", "knn", "rf", "adaboost", "nn", "gb", "xgb"]
for name in name_models:
    best_k = 0
    best_over = ""
    best_score = 0
    best_random = 0
    best_model = None
    file_name = ""
    sampling_method = ""
    best_X, best_y = None, None

    for r in random_ratio:
        print("-------------------------------------------------")
        print(f"{'Oversample':<20}{'Score':<20}Random {r} Name {name}")
        print("-------------------------------------------------")
        for underSampler in range(1,3):
            print(f"########## Changing sampling mode ##########")
            for name_over, over in overs:
                for k in range(2, 5):
                    model = load(path_models+f"{name}.joblib")
                    over.set_params(k_neighbors=k)
                    result = sampler(
                        model_name= name,
                        model = model,
                        overSampler = over,
                        sampling_strategy = r,
                        useUnderSampler = True if underSampler == 2 else False
                    )
                    score = result[0]
                    X_train_sample = result[1]
                    y_train_sample = result[2]
                    model = result[3]
                    if score > best_score:
                        best_k = k
                        best_over = name_over
                        best_score = score
                        best_random = r
                        best_model = copy.deepcopy(model)
                        sampling_method = "only oversampling" if underSampler == 1 else "undersampling + oversampling"
                        suffix = "_only_oversampling" if underSampler == 1 else "_sampling"
                        file_name = output_models.replace("models_output/", '').replace("/","") + suffix + ".txt"
                        best_X = X_train_sample
                        best_y = y_train_sample
                #in this case the score is the last score computed with k = 4
                print(f'{name_over:<20}{score:.3f}')

    # Save the dataset and model
    combination = f"_random_{best_over}_{name}"
    tmp = np.concatenate((best_X, np.expand_dims(best_y, 1)), axis=1)
    tmp = pd.DataFrame(tmp, columns=feat_names)

    # Current model's statistics
    print("\n")
    print(f"Name model:      \t{name}")
    print(f"Sampling method: {sampling_method }")
    print(f"Best rand_ratio: \t{best_random}")
    print(f"Best score:      \t{best_score}")
    print(f"Dataset size:    \t{len(best_y)}, {Counter(best_y)}")
    print(f"Combination:     \t{combination}")
    print("\n\n")

    # Evaluate the best model, save the data and the best model
    evaluate(best_model, best_X, best_y)
    evaluate(best_model, X_valid, y_valid)
    tmp.to_csv(path+f"train{combination}.csv")
    dump(best_model, path_models+f"{name}{combination}.joblib")
    with open(f"{output_models}{file_name}", 'a+') as f:
            with redirect_stdout(f):
                print (f"####################   {name}    #########################")
                print("Testing on training set:")
                evaluate(best_model, best_X, best_y)
                print("Testing on validation set:")
                evaluate(best_model, X_valid, y_valid)
                print("Parameters: {0}".format(model.get_params()))
                print (f"####################   {name}  END   #########################")
# Out:
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.665
# bordersmote         0.632
# svmsmote            0.675
# ########## Changing sampling mode ##########
# smote               0.665
# bordersmote         0.654
# svmsmote            0.657
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.646
# bordersmote         0.686
# svmsmote            0.681
# ########## Changing sampling mode ##########
# smote               0.670
# bordersmote         0.658
# svmsmote            0.682
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.662
# bordersmote         0.662
# svmsmote            0.671
# ########## Changing sampling mode ##########
# smote               0.664
# bordersmote         0.632
# svmsmote            0.663
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.683
# bordersmote         0.679
# svmsmote            0.664
# ########## Changing sampling mode ##########
# smote               0.629
# bordersmote         0.630
# svmsmote            0.668
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.672
# bordersmote         0.647
# svmsmote            0.676
# ########## Changing sampling mode ##########
# smote               0.644
# bordersmote         0.639
# svmsmote            0.646
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.669
# bordersmote         0.655
# svmsmote            0.684
# ########## Changing sampling mode ##########
# smote               0.666
# bordersmote         0.638
# svmsmote            0.654
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name lr
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.675
# bordersmote         0.662
# svmsmote            0.649
# ########## Changing sampling mode ##########
# smote               0.674
# bordersmote         0.661
# svmsmote            0.693
#
#
# Name model:      	lr
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.5
# Best score:      	0.6927493245274986
# Dataset size:    	2020, Counter({0.0: 1010, 1.0: 1010})
# Combination:     	_random_svmsmote_lr
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.785     0.716     0.749      1010
#          1.0      0.739     0.804     0.770      1010
#
#     accuracy                          0.760      2020
#    macro avg      0.762     0.760     0.759      2020
# weighted avg      0.762     0.760     0.759      2020
#
# auc macro 0.853
# confusion matrix
# [[723 287]
#  [198 812]]
#               precision    recall  f1-score   support
#
#          0.0      0.372     0.664     0.477       149
#          1.0      0.948     0.844     0.893      1072
#
#     accuracy                          0.822      1221
#    macro avg      0.660     0.754     0.685      1221
# weighted avg      0.877     0.822     0.842      1221
#
# auc macro 0.840
# confusion matrix
# [[ 99  50]
#  [167 905]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.598
# bordersmote         0.560
# svmsmote            0.381
# ########## Changing sampling mode ##########
# smote               0.510
# bordersmote         0.621
# svmsmote            0.633
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.618
# bordersmote         0.600
# svmsmote            0.476
# ########## Changing sampling mode ##########
# smote               0.637
# bordersmote         0.660
# svmsmote            0.645
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.540
# bordersmote         0.430
# svmsmote            0.579
# ########## Changing sampling mode ##########
# smote               0.514
# bordersmote         0.628
# svmsmote            0.641
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.507
# bordersmote         0.588
# svmsmote            0.443
# ########## Changing sampling mode ##########
# smote               0.656
# bordersmote         0.628
# svmsmote            0.626
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.613
# bordersmote         0.509
# svmsmote            0.466
# ########## Changing sampling mode ##########
# smote               0.660
# bordersmote         0.633
# svmsmote            0.646
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.449
# bordersmote         0.517
# svmsmote            0.558
# ########## Changing sampling mode ##########
# smote               0.657
# bordersmote         0.551
# svmsmote            0.627
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name svc
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.574
# bordersmote         0.594
# svmsmote            0.562
# ########## Changing sampling mode ##########
# smote               0.657
# bordersmote         0.623
# svmsmote            0.652
#
#
# Name model:      	svc
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.35
# Best score:      	0.6865729680272454
# Dataset size:    	2884, Counter({0.0: 1442, 1.0: 1442})
# Combination:     	_random_svmsmote_svc
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.798     0.621     0.698      1442
#          1.0      0.690     0.843     0.758      1442
#
#     accuracy                          0.732      2884
#    macro avg      0.744     0.732     0.728      2884
# weighted avg      0.744     0.732     0.728      2884
#
# auc macro 0.836
# confusion matrix
# [[ 895  547]
#  [ 227 1215]]
#               precision    recall  f1-score   support
#
#          0.0      0.386     0.604     0.471       149
#          1.0      0.940     0.867     0.902      1072
#
#     accuracy                          0.835      1221
#    macro avg      0.663     0.735     0.687      1221
# weighted avg      0.873     0.835     0.849      1221
#
# auc macro 0.810
# confusion matrix
# [[ 90  59]
#  [143 929]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.553
# bordersmote         0.584
# svmsmote            0.600
# ########## Changing sampling mode ##########
# smote               0.531
# bordersmote         0.549
# svmsmote            0.558
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.550
# bordersmote         0.576
# svmsmote            0.594
# ########## Changing sampling mode ##########
# smote               0.537
# bordersmote         0.572
# svmsmote            0.576
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.547
# bordersmote         0.565
# svmsmote            0.579
# ########## Changing sampling mode ##########
# smote               0.550
# bordersmote         0.541
# svmsmote            0.583
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.557
# bordersmote         0.581
# svmsmote            0.582
# ########## Changing sampling mode ##########
# smote               0.537
# bordersmote         0.538
# svmsmote            0.573
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.561
# bordersmote         0.582
# svmsmote            0.586
# ########## Changing sampling mode ##########
# smote               0.522
# bordersmote         0.522
# svmsmote            0.573
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.556
# bordersmote         0.566
# svmsmote            0.593
# ########## Changing sampling mode ##########
# smote               0.533
# bordersmote         0.530
# svmsmote            0.570
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name knn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.549
# bordersmote         0.569
# svmsmote            0.581
# ########## Changing sampling mode ##########
# smote               0.550
# bordersmote         0.520
# svmsmote            0.565
#
#
# Name model:      	knn
# Sampling method: only oversampling
# Best rand_ratio: 	0.45
# Best score:      	0.6002350677068247
# Dataset size:    	6988, Counter({1.0: 3494, 0.0: 3494})
# Combination:     	_random_svmsmote_knn
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.859     0.986     0.918      3494
#          1.0      0.983     0.838     0.905      3494
#
#     accuracy                          0.912      6988
#    macro avg      0.921     0.912     0.912      6988
# weighted avg      0.921     0.912     0.912      6988
#
# auc macro 0.992
# confusion matrix
# [[3444   50]
#  [ 565 2929]]
#               precision    recall  f1-score   support
#
#          0.0      0.260     0.530     0.349       149
#          1.0      0.924     0.790     0.852      1072
#
#     accuracy                          0.758      1221
#    macro avg      0.592     0.660     0.600      1221
# weighted avg      0.843     0.758     0.790      1221
#
# auc macro 0.695
# confusion matrix
# [[ 79  70]
#  [225 847]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.628
# bordersmote         0.632
# svmsmote            0.640
# ########## Changing sampling mode ##########
# smote               0.652
# bordersmote         0.662
# svmsmote            0.670
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.624
# bordersmote         0.626
# svmsmote            0.645
# ########## Changing sampling mode ##########
# smote               0.677
# bordersmote         0.677
# svmsmote            0.690
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.627
# bordersmote         0.630
# svmsmote            0.643
# ########## Changing sampling mode ##########
# smote               0.698
# bordersmote         0.706
# svmsmote            0.693
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.628
# bordersmote         0.627
# svmsmote            0.635
# ########## Changing sampling mode ##########
# smote               0.697
# bordersmote         0.701
# svmsmote            0.699
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.618
# bordersmote         0.633
# svmsmote            0.650
# ########## Changing sampling mode ##########
# smote               0.711
# bordersmote         0.702
# svmsmote            0.688
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.632
# bordersmote         0.625
# svmsmote            0.636
# ########## Changing sampling mode ##########
# smote               0.699
# bordersmote         0.689
# svmsmote            0.693
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name rf
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.620
# bordersmote         0.624
# svmsmote            0.637
# ########## Changing sampling mode ##########
# smote               0.692
# bordersmote         0.692
# svmsmote            0.702
#
#
# Name model:      	rf
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.4
# Best score:      	0.7112227975890704
# Dataset size:    	2524, Counter({0.0: 1262, 1.0: 1262})
# Combination:     	_random_smote_rf
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.977     0.941     0.959      1262
#          1.0      0.943     0.978     0.960      1262
#
#     accuracy                          0.960      2524
#    macro avg      0.960     0.960     0.960      2524
# weighted avg      0.960     0.960     0.960      2524
#
# auc macro 0.994
# confusion matrix
# [[1188   74]
#  [  28 1234]]
#               precision    recall  f1-score   support
#
#          0.0      0.449     0.537     0.489       149
#          1.0      0.934     0.909     0.921      1072
#
#     accuracy                          0.863      1221
#    macro avg      0.692     0.723     0.705      1221
# weighted avg      0.875     0.863     0.868      1221
#
# auc macro 0.848
# confusion matrix
# [[ 80  69]
#  [ 98 974]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.645
# bordersmote         0.662
# svmsmote            0.651
# ########## Changing sampling mode ##########
# smote               0.651
# bordersmote         0.678
# svmsmote            0.661
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.669
# bordersmote         0.672
# svmsmote            0.670
# ########## Changing sampling mode ##########
# smote               0.660
# bordersmote         0.676
# svmsmote            0.660
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.658
# bordersmote         0.647
# svmsmote            0.665
# ########## Changing sampling mode ##########
# smote               0.690
# bordersmote         0.668
# svmsmote            0.652
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.655
# bordersmote         0.657
# svmsmote            0.632
# ########## Changing sampling mode ##########
# smote               0.676
# bordersmote         0.659
# svmsmote            0.676
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.661
# bordersmote         0.683
# svmsmote            0.652
# ########## Changing sampling mode ##########
# smote               0.690
# bordersmote         0.659
# svmsmote            0.668
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.646
# bordersmote         0.647
# svmsmote            0.656
# ########## Changing sampling mode ##########
# smote               0.640
# bordersmote         0.678
# svmsmote            0.657
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name adaboost
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.691
# bordersmote         0.659
# svmsmote            0.665
# ########## Changing sampling mode ##########
# smote               0.664
# bordersmote         0.673
# svmsmote            0.684
#
#
# Name model:      	adaboost
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.3
# Best score:      	0.6998361103523627
# Dataset size:    	3366, Counter({0.0: 1683, 1.0: 1683})
# Combination:     	_random_smote_adaboost
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.873     0.835     0.854      1683
#          1.0      0.842     0.878     0.860      1683
#
#     accuracy                          0.857      3366
#    macro avg      0.857     0.857     0.857      3366
# weighted avg      0.857     0.857     0.857      3366
#
# auc macro 0.938
# confusion matrix
# [[1406  277]
#  [ 205 1478]]
#               precision    recall  f1-score   support
#
#          0.0      0.423     0.570     0.486       149
#          1.0      0.937     0.892     0.914      1072
#
#     accuracy                          0.853      1221
#    macro avg      0.680     0.731     0.700      1221
# weighted avg      0.874     0.853     0.862      1221
#
# auc macro 0.826
# confusion matrix
# [[ 85  64]
#  [116 956]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.647
# bordersmote         0.657
# svmsmote            0.666
# ########## Changing sampling mode ##########
# smote               0.660
# bordersmote         0.666
# svmsmote            0.660
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.662
# bordersmote         0.653
# svmsmote            0.672
# ########## Changing sampling mode ##########
# smote               0.659
# bordersmote         0.661
# svmsmote            0.661
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.646
# bordersmote         0.658
# svmsmote            0.681
# ########## Changing sampling mode ##########
# smote               0.656
# bordersmote         0.658
# svmsmote            0.658
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.658
# bordersmote         0.649
# svmsmote            0.664
# ########## Changing sampling mode ##########
# smote               0.650
# bordersmote         0.654
# svmsmote            0.675
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.664
# bordersmote         0.668
# svmsmote            0.655
# ########## Changing sampling mode ##########
# smote               0.665
# bordersmote         0.647
# svmsmote            0.654
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.652
# bordersmote         0.659
# svmsmote            0.667
# ########## Changing sampling mode ##########
# smote               0.642
# bordersmote         0.637
# svmsmote            0.655
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name nn
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.654
# bordersmote         0.656
# svmsmote            0.683
# ########## Changing sampling mode ##########
# smote               0.639
# bordersmote         0.668
# svmsmote            0.652
#
#
# Name model:      	nn
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.25
# Best score:      	0.6905421305081808
# Dataset size:    	4040, Counter({0.0: 2020, 1.0: 2020})
# Combination:     	_random_svmsmote_nn
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.856     0.861     0.858      2020
#          1.0      0.860     0.855     0.857      2020
#
#     accuracy                          0.858      4040
#    macro avg      0.858     0.858     0.858      4040
# weighted avg      0.858     0.858     0.858      4040
#
# auc macro 0.930
# confusion matrix
# [[1739  281]
#  [ 293 1727]]
#               precision    recall  f1-score   support
#
#          0.0      0.401     0.624     0.488       149
#          1.0      0.943     0.870     0.905      1072
#
#     accuracy                          0.840      1221
#    macro avg      0.672     0.747     0.697      1221
# weighted avg      0.877     0.840     0.854      1221
#
# auc macro 0.847
# confusion matrix
# [[ 93  56]
#  [139 933]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.649
# bordersmote         0.662
# svmsmote            0.688
# ########## Changing sampling mode ##########
# smote               0.678
# bordersmote         0.680
# svmsmote            0.681
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.655
# bordersmote         0.656
# svmsmote            0.679
# ########## Changing sampling mode ##########
# smote               0.692
# bordersmote         0.692
# svmsmote            0.692
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.647
# bordersmote         0.658
# svmsmote            0.672
# ########## Changing sampling mode ##########
# smote               0.695
# bordersmote         0.694
# svmsmote            0.683
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.653
# bordersmote         0.664
# svmsmote            0.677
# ########## Changing sampling mode ##########
# smote               0.700
# bordersmote         0.692
# svmsmote            0.690
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.655
# bordersmote         0.653
# svmsmote            0.679
# ########## Changing sampling mode ##########
# smote               0.695
# bordersmote         0.696
# svmsmote            0.694
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.646
# bordersmote         0.664
# svmsmote            0.682
# ########## Changing sampling mode ##########
# smote               0.679
# bordersmote         0.678
# svmsmote            0.691
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name gb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.652
# bordersmote         0.655
# svmsmote            0.680
# ########## Changing sampling mode ##########
# smote               0.685
# bordersmote         0.678
# svmsmote            0.677
#
#
# Name model:      	gb
# Sampling method: undersampling + oversampling
# Best rand_ratio: 	0.35
# Best score:      	0.7003003236846698
# Dataset size:    	2884, Counter({0.0: 1442, 1.0: 1442})
# Combination:     	_random_smote_gb
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.936     0.889     0.912      1442
#          1.0      0.894     0.940     0.916      1442
#
#     accuracy                          0.914      2884
#    macro avg      0.915     0.914     0.914      2884
# weighted avg      0.915     0.914     0.914      2884
#
# auc macro 0.972
# confusion matrix
# [[1282  160]
#  [  87 1355]]
#               precision    recall  f1-score   support
#
#          0.0      0.453     0.523     0.486       149
#          1.0      0.932     0.912     0.922      1072
#
#     accuracy                          0.865      1221
#    macro avg      0.693     0.718     0.704      1221
# weighted avg      0.874     0.865     0.869      1221
#
# auc macro 0.840
# confusion matrix
# [[ 78  71]
#  [ 94 978]]
# -------------------------------------------------
# Oversample          Score               Random 0.2 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.680
# bordersmote         0.672
# svmsmote            0.671
# ########## Changing sampling mode ##########
# smote               0.664
# bordersmote         0.674
# svmsmote            0.648
# -------------------------------------------------
# Oversample          Score               Random 0.25 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.678
# bordersmote         0.678
# svmsmote            0.667
# ########## Changing sampling mode ##########
# smote               0.647
# bordersmote         0.657
# svmsmote            0.641
# -------------------------------------------------
# Oversample          Score               Random 0.3 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.666
# bordersmote         0.672
# svmsmote            0.670
# ########## Changing sampling mode ##########
# smote               0.637
# bordersmote         0.653
# svmsmote            0.632
# -------------------------------------------------
# Oversample          Score               Random 0.35 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.677
# bordersmote         0.688
# svmsmote            0.675
# ########## Changing sampling mode ##########
# smote               0.636
# bordersmote         0.621
# svmsmote            0.631
# -------------------------------------------------
# Oversample          Score               Random 0.4 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.687
# bordersmote         0.671
# svmsmote            0.678
# ########## Changing sampling mode ##########
# smote               0.615
# bordersmote         0.613
# svmsmote            0.610
# -------------------------------------------------
# Oversample          Score               Random 0.45 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.678
# bordersmote         0.669
# svmsmote            0.680
# ########## Changing sampling mode ##########
# smote               0.624
# bordersmote         0.604
# svmsmote            0.607
# -------------------------------------------------
# Oversample          Score               Random 0.5 Name xgb
# -------------------------------------------------
# ########## Changing sampling mode ##########
# smote               0.680
# bordersmote         0.660
# svmsmote            0.678
# ########## Changing sampling mode ##########
# smote               0.603
# bordersmote         0.605
# svmsmote            0.608
#
#
# Name model:      	xgb
# Sampling method: only oversampling
# Best rand_ratio: 	0.5
# Best score:      	0.691023166023166
# Dataset size:    	6988, Counter({1.0: 3494, 0.0: 3494})
# Combination:     	_random_smote_xgb
#
#
#
#               precision    recall  f1-score   support
#
#          0.0      0.867     0.947     0.905      3494
#          1.0      0.942     0.855     0.896      3494
#
#     accuracy                          0.901      6988
#    macro avg      0.904     0.901     0.901      6988
# weighted avg      0.904     0.901     0.901      6988
#
# auc macro 0.976
# confusion matrix
# [[3310  184]
#  [ 508 2986]]
#               precision    recall  f1-score   support
#
#          0.0      0.398     0.591     0.476       149
#          1.0      0.939     0.876     0.906      1072
#
#     accuracy                          0.841      1221
#    macro avg      0.669     0.733     0.691      1221
# weighted avg      0.873     0.841     0.854      1221
#
# auc macro 0.836
# confusion matrix
# [[ 88  61]
#  [133 939]]
